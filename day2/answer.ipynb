# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain_community in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: bs4 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.0.2)
# Requirement already satisfied: langchain-openai in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.1.8)
# Requirement already satisfied: langchain-chroma in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.1.1)
# Requirement already satisfied: sentence_transformers in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.5 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.7 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (0.2.9)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (0.1.80)
# Requirement already satisfied: numpy<2,>=1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 1)) (8.4.1)
# Requirement already satisfied: beautifulsoup4 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from bs4->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: openai<2.0.0,>=1.26.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain-openai->-r requirements.txt (line 3)) (1.34.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain-openai->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: chromadb<0.6.0,>=0.4.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain-chroma->-r requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain-chroma->-r requirements.txt (line 4)) (0.111.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 5)) (4.41.2)
# Requirement already satisfied: tqdm in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 5)) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: scipy in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 5)) (0.23.4)
# Requirement already satisfied: Pillow in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 5)) (10.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: build>=1.0.3 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: pydantic>=1.9 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (2.7.4)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.7.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.30.1)
# Requirement already satisfied: posthog>=2.4.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.18.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (3.10.5)
# Requirement already satisfied: httpx>=0.27.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.27.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 1)) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 4)) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 4)) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 4)) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 4)) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: filelock in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r requirements.txt (line 5)) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r requirements.txt (line 5)) (2024.5.0)
# Requirement already satisfied: packaging>=20.9 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r requirements.txt (line 5)) (24.1)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain<0.3.0,>=0.2.5->langchain_community->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.7->langchain_community->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.26.0->langchain-openai->-r requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.26.0->langchain-openai->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: sniffio in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.26.0->langchain-openai->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain_community->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain_community->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain_community->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain_community->-r requirements.txt (line 1)) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain_community->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai->-r requirements.txt (line 3)) (2024.5.15)
# Requirement already satisfied: sympy in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 5)) (1.12.1)
# Requirement already satisfied: networkx in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 5)) (3.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers->-r requirements.txt (line 5)) (0.4.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from beautifulsoup4->bs4->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from scikit-learn->sentence_transformers->-r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from scikit-learn->sentence_transformers->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.26.0->langchain-openai->-r requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: pyproject_hooks in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from email_validator>=2.0.0->fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: httpcore==1.* in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from jinja2>=2.11.2->fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 4)) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain_community->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (2.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (3.2.2)
# Requirement already satisfied: coloredlogs in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (24.3.25)
# Requirement already satisfied: protobuf in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (4.25.3)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.63.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (65.5.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from pydantic>=1.9->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from pydantic>=1.9->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (2.18.4)
# Requirement already satisfied: click>=8.0.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (13.7.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (12.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (4.9)
# Requirement already satisfied: zipp>=0.5 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (3.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (2.18.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (10.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 4)) (0.6.0)

# %%
import os

from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
OPENAI_API_KEY = ""

# %%
llama3_format_template = "<|begin_of_text|><|start_header_id|>user<|end_header_id|>{prompt}<|eot_id|><|start_header_id|>assistant<|end_header_id|>"

# %%
os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

urls = [
    "https://lilianweng.github.io/posts/2023-06-23-agent/",
    "https://lilianweng.github.io/posts/2023-03-15-prompt-engineering/",
    "https://lilianweng.github.io/posts/2023-10-25-adv-attack-llm/",
    ]

docs = [WebBaseLoader(url).load() for url in urls]
docs_list = [item for sublist in docs for item in sublist]

text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    # Set a really small chunk size, just to show.
    chunk_size=100,
    chunk_overlap=50,
)
doc_splits = text_splitter.split_documents(docs_list)


embeddings_model = OpenAIEmbeddings()

vectorstore = Chroma.from_documents(
    documents=doc_splits,
    embedding=embeddings_model,
    collection_name="sol_day2",
    persist_directory="./chroma_db",
)

query = "llm agent memory"

retriever = vectorstore.as_retriever()
docs = retriever.get_relevant_documents(query)

# Common setting for chains
local_llm = "llama3"
llm = ChatOllama(model=local_llm, format="json", temperature=0)
parser = JsonOutputParser()

# Relevance check
prompt = PromptTemplate(
    template=llama3_format_template.format(
        prompt="""Check the <query> is relevant to retrieved <context>. Answer with "yes" or "no" in json format(key: relevance).
        Here is the question: {query}
        Here is the context: {context}"""
    ),
    input_variables=["query", "context"],
)
relevant_chain = prompt | llm | parser
valid_doc_list = []
for doc in docs:
    doc_text = doc.page_content
    is_relevant = relevant_chain.invoke({"query": query, "context": doc_text})["relevance"]
    if is_relevant == "yes":
        valid_doc_list.append(doc)

# Drop duplicate in context
context_list = []
for doc in valid_doc_list:
    if doc.page_content not in [context.page_content for context in context_list]:
        context_list.append(doc)

# If context_list is not empty
if context_list:
    while 1:
        # Answer
        context = "\n".join([doc.page_content for doc in context_list])
        prompt = PromptTemplate(
            template=llama3_format_template.format(
                prompt="""Answer to the <query> with <context>. Answer in json format(key: answer).
                Here is the question: {query}
                Here is the context: {context}"""
            ),
            input_variables=["query", "context"],
        )
        question_chain = prompt | llm | parser
        answer = question_chain.invoke(
            {"query": "What is agent memory?", "context": context}
            )["answer"]
        
        # Halucination check
        hallucination_prompt = PromptTemplate(
            template=llama3_format_template.format(
                prompt="""Check the <answer> has halllucination or not. Answer with "yes" or "no" in json format(key: hallucination).
                Here is the answer: {answer}"""
            ),
            input_variables=["answer"],
        )
        hallucination_chain = hallucination_prompt | llm | parser
        hallucination = hallucination_chain.invoke({"answer": answer})["hallucination"]

        if hallucination == "no":
            break    

    print("="*50)
    print(f"Answer: {answer}")
    for idx, context in enumerate(context_list):
        print("="*50)
        print(f"Context {idx+1}")
        print(context)
        print(f"Content: {context.page_content}")
        print(f"Source: {context.metadata['source']}")
    print("="*50)

else:
    print("No")
# Out:
# /Users/sol.ty/Desktop/workspace/ai-advanced/.venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ==================================================
# Answer: Agent memory refers to the component of an agent system that enables it to behave conditioned on past experience, allowing it to learn from its interactions and make decisions based on its history.
# ==================================================
# Context 1
# page_content='The design of generative agents combines LLM with memory, planning and reflection mechanisms to enable agents to behave conditioned on past experience, as well as to interact with other agents.' metadata={'description': 'Building agents with LLM (large language model) as its core controller is a cool concept. Several proof-of-concepts demos, such as AutoGPT, GPT-Engineer and BabyAGI, serve as inspiring examples. The potentiality of LLM extends beyond generating well-written copies, stories, essays and programs; it can be framed as a powerful general problem solver.\nAgent System Overview In a LLM-powered autonomous agent system, LLM functions as the agent’s brain, complemented by several key components:', 'language': 'en', 'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'title': "LLM Powered Autonomous Agents | Lil'Log"}
# Content: The design of generative agents combines LLM with memory, planning and reflection mechanisms to enable agents to behave conditioned on past experience, as well as to interact with other agents.
# Source: https://lilianweng.github.io/posts/2023-06-23-agent/
# ==================================================
# Context 2
# page_content='LLM Powered Autonomous Agents\n    \nDate: June 23, 2023  |  Estimated Reading Time: 31 min  |  Author: Lilian Weng\n\n\n \n\n\nTable of Contents\n\n\n\nAgent System Overview\n\nComponent One: Planning\n\nTask Decomposition\n\nSelf-Reflection\n\n\nComponent Two: Memory\n\nTypes of Memory\n\nMaximum Inner Product Search (MIPS)' metadata={'description': 'Building agents with LLM (large language model) as its core controller is a cool concept. Several proof-of-concepts demos, such as AutoGPT, GPT-Engineer and BabyAGI, serve as inspiring examples. The potentiality of LLM extends beyond generating well-written copies, stories, essays and programs; it can be framed as a powerful general problem solver.\nAgent System Overview In a LLM-powered autonomous agent system, LLM functions as the agent’s brain, complemented by several key components:', 'language': 'en', 'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'title': "LLM Powered Autonomous Agents | Lil'Log"}
# Content: LLM Powered Autonomous Agents
#
# Date: June 23, 2023  |  Estimated Reading Time: 31 min  |  Author: Lilian Weng
#
#
#
#
#
# Table of Contents
#
#
#
# Agent System Overview
#
# Component One: Planning
#
# Task Decomposition
#
# Self-Reflection
#
#
# Component Two: Memory
#
# Types of Memory
#
# Maximum Inner Product Search (MIPS)
# Source: https://lilianweng.github.io/posts/2023-06-23-agent/
# ==================================================
# Context 3
# page_content='Agent System Overview#\nIn a LLM-powered autonomous agent system, LLM functions as the agent’s brain, complemented by several key components:' metadata={'description': 'Building agents with LLM (large language model) as its core controller is a cool concept. Several proof-of-concepts demos, such as AutoGPT, GPT-Engineer and BabyAGI, serve as inspiring examples. The potentiality of LLM extends beyond generating well-written copies, stories, essays and programs; it can be framed as a powerful general problem solver.\nAgent System Overview In a LLM-powered autonomous agent system, LLM functions as the agent’s brain, complemented by several key components:', 'language': 'en', 'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'title': "LLM Powered Autonomous Agents | Lil'Log"}
# Content: Agent System Overview#
# In a LLM-powered autonomous agent system, LLM functions as the agent’s brain, complemented by several key components:
# Source: https://lilianweng.github.io/posts/2023-06-23-agent/
# ==================================================
# Context 4
# page_content='Boiko et al. (2023) also looked into LLM-empowered agents for scientific discovery, to handle autonomous design, planning, and performance of complex scientific experiments. This agent can use tools to browse the Internet, read documentation, execute code, call robotics experimentation APIs and leverage other LLMs.\nFor example, when requested to "develop a novel anticancer drug", the model came up with the following reasoning steps:' metadata={'description': 'Building agents with LLM (large language model) as its core controller is a cool concept. Several proof-of-concepts demos, such as AutoGPT, GPT-Engineer and BabyAGI, serve as inspiring examples. The potentiality of LLM extends beyond generating well-written copies, stories, essays and programs; it can be framed as a powerful general problem solver.\nAgent System Overview In a LLM-powered autonomous agent system, LLM functions as the agent’s brain, complemented by several key components:', 'language': 'en', 'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'title': "LLM Powered Autonomous Agents | Lil'Log"}
# Content: Boiko et al. (2023) also looked into LLM-empowered agents for scientific discovery, to handle autonomous design, planning, and performance of complex scientific experiments. This agent can use tools to browse the Internet, read documentation, execute code, call robotics experimentation APIs and leverage other LLMs.
# For example, when requested to "develop a novel anticancer drug", the model came up with the following reasoning steps:
# Source: https://lilianweng.github.io/posts/2023-06-23-agent/
# ==================================================
